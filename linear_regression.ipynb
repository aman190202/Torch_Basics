# %%
import torch
import torch.nn as nn
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
#preparing data

X_numpy, y_numpy= datasets.make_regression(n_samples=100, n_features=1, noise =20, random_state=1)

X = torch.from_numpy(X_numpy.astype(np.float32))
y = torch.from_numpy(y_numpy.astype(np.float32))
y = y.view(y.shape[0],1)

n_samples, n_features= X.shape

# %%
input_size= n_features
output_size=1
model= nn.Linear(input_size,output_size)

# %%
learning_rate=0.01
criterion= nn.MSELoss()
optimizer= torch.optim.SGD(model.parameters(), lr = learning_rate)

# %%
num_epochs=100
for epoch in range(num_epochs):
    y_pred=model(X)
    loss= criterion(y_pred,y)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    print(f'epoch : {epoch+1}, loss = {loss.item():.4f} ')
# Out:
# epoch : 1, loss = 5631.1270
# epoch : 2, loss = 5462.8462
# epoch : 3, loss = 5299.9614
# epoch : 4, loss = 5142.2974
# epoch : 5, loss = 4989.6860
# epoch : 6, loss = 4841.9624
# epoch : 7, loss = 4698.9688
# epoch : 8, loss = 4560.5522
# epoch : 9, loss = 4426.5640
# epoch : 10, loss = 4296.8604
# epoch : 11, loss = 4171.3042
# epoch : 12, loss = 4049.7610
# epoch : 13, loss = 3932.1001
# epoch : 14, loss = 3818.1975
# epoch : 15, loss = 3707.9307
# epoch : 16, loss = 3601.1831
# epoch : 17, loss = 3497.8416
# epoch : 18, loss = 3397.7949
# epoch : 19, loss = 3300.9385
# epoch : 20, loss = 3207.1675
# epoch : 21, loss = 3116.3853
# epoch : 22, loss = 3028.4937
# epoch : 23, loss = 2943.4006
# epoch : 24, loss = 2861.0154
# epoch : 25, loss = 2781.2515
# epoch : 26, loss = 2704.0244
# epoch : 27, loss = 2629.2529
# epoch : 28, loss = 2556.8577
# epoch : 29, loss = 2486.7627
# epoch : 30, loss = 2418.8945
# epoch : 31, loss = 2353.1809
# epoch : 32, loss = 2289.5537
# epoch : 33, loss = 2227.9458
# epoch : 34, loss = 2168.2920
# epoch : 35, loss = 2110.5303
# epoch : 36, loss = 2054.5996
# epoch : 37, loss = 2000.4419
# epoch : 38, loss = 1948.0001
# epoch : 39, loss = 1897.2192
# epoch : 40, loss = 1848.0465
# epoch : 41, loss = 1800.4304
# epoch : 42, loss = 1754.3214
# epoch : 43, loss = 1709.6709
# epoch : 44, loss = 1666.4330
# epoch : 45, loss = 1624.5624
# epoch : 46, loss = 1584.0150
# epoch : 47, loss = 1544.7493
# epoch : 48, loss = 1506.7239
# epoch : 49, loss = 1469.8994
# epoch : 50, loss = 1434.2377
# epoch : 51, loss = 1399.7021
# epoch : 52, loss = 1366.2561
# epoch : 53, loss = 1333.8656
# epoch : 54, loss = 1302.4965
# epoch : 55, loss = 1272.1163
# epoch : 56, loss = 1242.6945
# epoch : 57, loss = 1214.1993
# epoch : 58, loss = 1186.6025
# epoch : 59, loss = 1159.8745
# epoch : 60, loss = 1133.9885
# epoch : 61, loss = 1108.9175
# epoch : 62, loss = 1084.6356
# epoch : 63, loss = 1061.1177
# epoch : 64, loss = 1038.3400
# epoch : 65, loss = 1016.2784
# epoch : 66, loss = 994.9107
# epoch : 67, loss = 974.2147
# epoch : 68, loss = 954.1692
# epoch : 69, loss = 934.7536
# epoch : 70, loss = 915.9479
# epoch : 71, loss = 897.7330
# epoch : 72, loss = 880.0899
# epoch : 73, loss = 863.0007
# epoch : 74, loss = 846.4478
# epoch : 75, loss = 830.4144
# epoch : 76, loss = 814.8842
# epoch : 77, loss = 799.8409
# epoch : 78, loss = 785.2693
# epoch : 79, loss = 771.1546
# epoch : 80, loss = 757.4822
# epoch : 81, loss = 744.2385
# epoch : 82, loss = 731.4096
# epoch : 83, loss = 718.9827
# epoch : 84, loss = 706.9448
# epoch : 85, loss = 695.2840
# epoch : 86, loss = 683.9881
# epoch : 87, loss = 673.0458
# epoch : 88, loss = 662.4460
# epoch : 89, loss = 652.1777
# epoch : 90, loss = 642.2307
# epoch : 91, loss = 632.5947
# epoch : 92, loss = 623.2599
# epoch : 93, loss = 614.2170
# epoch : 94, loss = 605.4567
# epoch : 95, loss = 596.9702
# epoch : 96, loss = 588.7488
# epoch : 97, loss = 580.7842
# epoch : 98, loss = 573.0684
# epoch : 99, loss = 565.5934
# epoch : 100, loss = 558.3519

# %%
predicted= model(X).detach().numpy()
plt.plot(X_numpy,y_numpy,'ro')
plt.plot(X_numpy,predicted,'b')
plt.show()
