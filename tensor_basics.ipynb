# %%
import torch

x = torch.empty(2,2,3)
print(x)
# Out:
# tensor([[[4.3403e-34, 1.4013e-45, 3.8115e-34],
#          [1.4013e-45, 4.3404e-34, 1.4013e-45]],
#
#         [[3.8118e-34, 1.4013e-45, 4.3406e-34],
#          [1.4013e-45, 8.1116e-36, 1.4013e-45]]])

# %%
torch.rand(2,2)
# Out:
# tensor([[0.2688, 0.6968],
#         [0.1507, 0.7348]])

# %%
torch.zeros(2,2)
# Out:
# tensor([[0., 0.],
#         [0., 0.]])

# %%
torch.ones(2,2)
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
x=torch.tensor([2.5,0.1])
x
# Out:
# tensor([2.5000, 0.1000])
