# %%
import torch
import torch.nn as nn
import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
bc = datasets.load_breast_cancer()
X,y= bc.data,bc.target

n_samples, n_featurs=X.shape

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2,random_state=1234)

# %%
sc= StandardScaler()
X_train= sc.fit_transform(X_train)
X_test= sc.fit_transform(X_test)

X_train=torch.from_numpy(X_train.astype(np.float32))
X_test=torch.from_numpy(X_test.astype(np.float32))
y_train=torch.from_numpy(y_train.astype(np.float32))
y_test=torch.from_numpy(y_test.astype(np.float32))

y_train = y_train.view(y_train.shape[0],1)
y_test = y_test.view(y_test.shape[0],1)

# %%
class Logistic(nn.Module):
    
    def __init__(self,input):
        super(Logistic,self).__init__()
        self.linear= nn.Linear(input,1)
    def forward(self,x):
        y_predicted= torch.sigmoid(self.linear(x))
        return y_predicted

model=Logistic(n_featurs)

# %%
criterion = nn.BCELoss()
learning_rate=0.01
optimizer= torch.optim.SGD(model.parameters(),lr= learning_rate)

# %%
num_epochs=1000
for epochs in range(num_epochs):
    y_pred=model(X_train)
    loss=criterion(y_pred,y_train)

    loss.backward()

    optimizer.step()

    optimizer.zero_grad()

    if(epochs%100 == 0):
        print(f'epoch {epochs+1}, loss {loss.item():.4f} ')
# Out:
# epoch 1, loss 0.2401
# epoch 101, loss 0.1788
# epoch 201, loss 0.1494
# epoch 301, loss 0.1316
# epoch 401, loss 0.1195
# epoch 501, loss 0.1106
# epoch 601, loss 0.1038
# epoch 701, loss 0.0983
# epoch 801, loss 0.0938
# epoch 901, loss 0.0900

# %%
with torch.no_grad():
    y_predicted=model(X_test)
    y_predicted_cls= y_predicted.round()
    acc = y_predicted_cls.eq(y_test).sum() / float(y_test.shape[0])
    print(f'Accuracy : {acc:.3f} ')
# Out:
# Accuracy : 0.939
