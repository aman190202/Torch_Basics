# %%
import torch
import torch.nn as nn 
from torchvision import transforms

# %% [markdown]
# #### Link to the dataset : https://www.kaggle.com/datasets/grassknoted/asl-alphabet

# %%
import splitfolders
splitfolders.ratio('LargeDataset/asl_alphabet_train/asl_alphabet_train/', output="LargeDataset/asl/", seed=1337, ratio=(.8, 0.2))
# Out:
# Copying files: 87000 files [00:25, 3423.68 files/s]
