# %%
import numpy as np

# %%
X = np.array([1,2,3,4],dtype=np.float32)
Y = np.array([13,26,39,52],dtype=np.float32)

# %%
w=0.0

def forward(x):
    return w*x

def loss(y,y_pred):
    return ((y_pred-y)**2).mean()

def gradient(x,y,y_pred):
    return np.dot(2*x,y_pred-y).mean()

# %%
print(f'Prediction before training : f(5) = {forward(5):.3f}')
# Out:
# Prediction before training : f(5) = 0.000

# %%
learning_rate=0.01
n_iters=10

for epoch in range(n_iters):
    y_pred=forward(X)
    l= loss(Y,y_pred)
    dw=gradient(X,Y,y_pred)
    w-= learning_rate * dw
    print(f'Epoch {epoch+1}, w = {w:.3f}, loss = {l:.3f}')

print(f'Prediction after training f(5) : {forward(5):.3f}')
# Out:
# Epoch 1, w = 7.800, loss = 1267.500
# Epoch 2, w = 10.920, loss = 202.800
# Epoch 3, w = 12.168, loss = 32.448
# Epoch 4, w = 12.667, loss = 5.192
# Epoch 5, w = 12.867, loss = 0.831
# Epoch 6, w = 12.947, loss = 0.133
# Epoch 7, w = 12.979, loss = 0.021
# Epoch 8, w = 12.991, loss = 0.003
# Epoch 9, w = 12.997, loss = 0.001
# Epoch 10, w = 12.999, loss = 0.000
# Prediction after training f(5) : 64.993
